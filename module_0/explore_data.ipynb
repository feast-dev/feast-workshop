# %%
import pandas as pd
df = pd.read_parquet("infra/driver_stats.parquet")
df.head().T
# Out:
#                                              0                           1  \
# event_timestamp      2022-02-27 15:00:00+00:00   2022-02-27 16:00:00+00:00
# driver_id                                 1005                        1005
# conv_rate                             0.142214                    0.349267
# acc_rate                              0.408987                    0.734021
# created             2022-03-14 15:21:25.842000  2022-03-14 15:21:25.842000
# day                                 2022-02-27                  2022-02-27
# miles_driven                         24.817618                    8.293352
# daily_miles_driven                  150.587752                  150.587752
#
#                                              2                           3  \
# event_timestamp      2022-02-27 17:00:00+00:00   2022-02-27 18:00:00+00:00
# driver_id                                 1005                        1005
# ...
